# %% [markdown]
# **<span style="font-size:30px;">Amazon Sales Performance Analysis</span>**

# %% [markdown]
# <span style="font-size:20px;">Business Problem Statement:</span>

# %% [markdown]
# In an increasingly competitive and dynamic market, Amazon needs to continuously refine its sales strategies to maintain an edge. By utilizing data-driven insights, Amazon can optimize its profitability, improve operational efficiency, and ensure customer satisfaction. A comprehensive analysis of sales data is essential for identifying growth opportunities, boosting profit margins, and improving sales tactics to stay competitive.

# %% [markdown]
# <span style="font-size:20px;">Understanding the Problem:</span>

# %% [markdown]
# Amazon's current sales performance requires a deep analysis of various factors like time trends, regional differences, product types, and sales channels. The challenge is understanding how these factors impact sales, costs, and profitability. By gaining insights into these aspects, Amazon can fine-tune its strategies to outpace competitors and capitalize on shifting market trends.

# %% [markdown]
# <span style="font-size:20px;">Project Statement:</span>

# %% [markdown]
# This project will analyze Amazon’s sales data with a focus on:
#
# **Trend Analysis**: Examine monthly, yearly, and combined sales trends to uncover patterns, seasonal effects, and growth opportunities.
#
# **Key Metrics Extraction**: Analyze total revenue, cost, and profit to evaluate performance and identify key drivers of success.
#
# **Factor Analysis**: Assess the influence of region, product type, sales channel, and order priority on overall sales and profitability.
#
# The analysis will generate actionable insights that help refine Amazon's sales strategies, enhance profitability, and adapt to market conditions. Advanced visualizations will support strategic decision-making and improve operational efficiency.

# %% [markdown]
# **<span style="font-size:24px;">Importing Required Libraries</span>**

# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('Amazon Sales data.csv')

# %% [markdown]
# **<span style="font-size:24px;">Data Exploration</span>**

# %%
data.head(10)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %%
data.shape
# Out:
# (100, 14)

# %% [markdown]
# Observation: It contains 100 rows and 14 columns in a dataset

# %%
columns=list(data)
columns
# Out:
# ['Region',
#  'Country',
#  'Item Type',
#  'Sales Channel',
#  'Order Priority',
#  'Order Date',
#  'Order ID',
#  'Ship Date',
#  'Units Sold',
#  'Unit Price',
#  'Unit Cost',
#  'Total Revenue',
#  'Total Cost',
#  'Total Profit']

# %%
data.describe()# Generates descriptive statistics for the DataFrame 'data'
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
data.info()# Displays a concise summary of the DataFrame 'data'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Region            100 non-null    category
#  1   Country           100 non-null    category
#  2   Item Type         100 non-null    category
#  3   Sales Channel     100 non-null    category
#  4   Order Priority    100 non-null    category
#  5   Order Date        100 non-null    datetime64[ns]
#  6   Order ID          100 non-null    int64
#  7   Ship Date         100 non-null    datetime64[ns]
#  8   Units Sold        100 non-null    int32
#  9   Unit Price        100 non-null    int32
#  10  Unit Cost         100 non-null    int32
#  11  Total Revenue     100 non-null    int32
#  12  Total Cost        100 non-null    int32
#  13  Total Profit      100 non-null    int32
#  14  Order Year        100 non-null    int32
#  15  Order Month       100 non-null    int32
# ...

# %%
# Converting to 'datetime' type
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
# Converting to 'category' type
data['Region'] = data['Region'].astype('category')
data['Country'] = data['Country'].astype('category')
data['Item Type'] = data['Item Type'].astype('category')
data['Sales Channel'] = data['Sales Channel'].astype('category')
data['Order Priority'] = data['Order Priority'].astype('category')

# %%
# Converting Selected Columns to 'Integer' Data Type
data['Unit Price']=data['Unit Price'].astype('int')
data['Units Sold']=data['Units Sold'].astype('int')
data['Unit Cost']=data['Unit Cost'].astype('int')
data['Total Revenue']=data['Total Revenue'].astype('int')
data['Total Cost']=data['Total Cost'].astype('int')
data['Total Profit']=data['Total Profit'].astype('int')

# %% [markdown]
# **<span style="font-size:24px;">Data Cleaning</span>**

# %%
#checking null values
nulls=data.isnull().sum()
print(nulls)
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %% [markdown]
# Observation: There are no null values in a dataset

# %%
#checking zero values
zeros=(data[columns[1:14]] == 0).sum()
print(zeros)
# Out:
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %% [markdown]
# Observation: There are no zero values in a dataset

# %%
# Check for duplicate rows
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit]
# Index: []

# %% [markdown]
# Observation: There are no duplicate rows in a dataset

# %%
# Check for duplicate values in the 'Order ID' column
data[data.duplicated(['Order ID'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit]
# Index: []

# %% [markdown]
# Observation: There are no duplicate values in 'OrderID' column in a dataset

# %%
# Check for duplicate rows based on all columns
data[data.duplicated(subset=None,keep=False) ] # 'subset=None' checks across all columns
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit]
# Index: []

# %% [markdown]
# Observation: There are no duplicate rows based on all columns in a dataset

# %%
# Extract month and year from the 'Order Date'
data['Order Year'] = data['Order Date'].dt.year
data['Order Month'] = data['Order Date'].dt.month
data['Order Year_Month'] = data['Order Date'].dt.strftime('%Y-%m')

# %%
# Columns to analyze for outliers
columns_to_analyze = ['Total Revenue', 'Total Cost', 'Total Profit']

# Plotting boxplots for each column to analyse outliers
for col in columns_to_analyze:
    plt.figure(figsize=(4, 2))
    sns.boxplot(data[col])
    plt.title(f'Boxplot for {col}')
    plt.show()

# %%
# Columns to analyze for outliers
columns_to_analyze = ['Total Revenue', 'Total Cost', 'Total Profit']
outlier_records = pd.DataFrame()

# Loop through each column
for col in columns_to_analyze:
    Q1 = np.percentile(data[col], 25)
    Q3 = np.percentile(data[col], 75)
    IQR = Q3 - Q1
    low = Q1 - 1.5 * IQR
    upp = Q3 + 1.5 * IQR
    
    # Identify outliers
    outliers = data[(data[col] < low) | (data[col] > upp)]
    
    # Append outliers to the outlier_records dataframe
    outlier_records = pd.concat([outlier_records, outliers], ignore_index=False)

# Remove outliers from the original data
Clean_data = data[~data.index.isin(outlier_records.index)]

Clean_data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# Observation:Seven outliers were removed from the dataset, improving data quality by eliminating extreme values that could skew the analysis.

# %%
# Exporting the Cleaned Dataframe for making dashboard in Power BI
Clean_data.to_csv('Clean_Data.csv',index=False)

# %% [markdown]
# **<span style="font-size:20px;">Initial Observations And Descriptive Statistics </span>**

# %%
# Unique counts for categorical variables
unique_order_ids = Clean_data['Order ID'].nunique()
unique_item_types = Clean_data['Item Type'].nunique()
unique_countries = Clean_data['Country'].nunique()
unique_regions = Clean_data['Region'].nunique()
unique_sales_channels = Clean_data['Sales Channel'].nunique()
unique_order_priorities = Clean_data['Order Priority'].nunique()

# Print unique counts
print(f"Unique Order IDs: {unique_order_ids}")
print(f"Unique Item Types: {unique_item_types}")
print(f"Unique Countries: {unique_countries}")
print(f"Unique Regions: {unique_regions}")
print(f"Unique Sales Channels: {unique_sales_channels}")
print(f"Unique Order Priorities: {unique_order_priorities}")
# Out:
# Unique Order IDs: 93
# Unique Item Types: 12
# Unique Countries: 72
# Unique Regions: 7
# Unique Sales Channels: 2
# Unique Order Priorities: 4

# %%
# Frequency Counts for Categorical Columns
item_type_counts = Clean_data['Item Type'].value_counts()
country_counts = Clean_data['Country'].value_counts()
region_counts = Clean_data['Region'].value_counts()
sales_channel_counts = Clean_data['Sales Channel'].value_counts()
order_priority_counts = Clean_data['Order Priority'].value_counts()

# Print frequency counts
print("Item Type Frequency Distribution:\n", item_type_counts)
print("\nCountry Frequency Distribution:\n", country_counts)
print("\nRegion Frequency Distribution:\n", region_counts)
print("\nSales Channel Frequency Distribution:\n", sales_channel_counts)
print("\nOrder Priority Frequency Distribution:\n", order_priority_counts)
# Out:
# Item Type Frequency Distribution:
#  Item Type
# Clothes            13
# Office Supplies    11
# Fruits             10
# Personal Care      10
# Cosmetics           9
# Beverages           8
# Baby Food           7
# Cereal              7
# Household           7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: count, dtype: int64
#
# Country Frequency Distribution:
#  Country
# The Gambia               4
# Australia                3
# Sao Tome and Principe    3
# Mexico                   3
# Sierra Leone             3
#                         ..
# Zambia                   1
# Samoa                    0
# Pakistan                 0
# Lithuania                0
# Iceland                  0
# Name: count, Length: 76, dtype: int64
#
# Region Frequency Distribution:
#  Region
# Sub-Saharan Africa                   36
# Europe                               19
# Asia                                 10
# Australia and Oceania                10
# ...

# %%
#Mode (Most Frequent Value)
# Calculate mode for categorical variables
mode_item_type = Clean_data['Item Type'].mode()[0]
mode_country = Clean_data['Country'].mode()[0]
mode_region = Clean_data['Region'].mode()[0]
mode_sales_channel = Clean_data['Sales Channel'].mode()[0]
mode_order_priority = Clean_data['Order Priority'].mode()[0]

# Print mode
print(f"Most Common Item Type: {mode_item_type}")
print(f"Most Common Country: {mode_country}")
print(f"Most Common Region: {mode_region}")
print(f"Most Common Sales Channel: {mode_sales_channel}")
print(f"Most Common Order Priority: {mode_order_priority}")
# Out:
# Most Common Item Type: Clothes
# Most Common Country: The Gambia
# Most Common Region: Sub-Saharan Africa
# Most Common Sales Channel: Online
# Most Common Order Priority: H

# %%
# 3. Top Categories based on no of orders
top_item_types = Clean_data['Item Type'].value_counts().head(3)
top_countries = Clean_data['Country'].value_counts().head(3)
top_regions = Clean_data['Region'].value_counts().head(3)

print("\nTop 3 Item Types:")
print(top_item_types)

print("\nTop 3 Countries:")
print(top_countries)

print("\nTop 3 Regions:")
print(top_regions)
# Out:
# Top 3 Item Types:
# Item Type
# Clothes            13
# Office Supplies    11
# Fruits             10
# Name: count, dtype: int64
#
# Top 3 Countries:
# Country
# The Gambia               4
# Australia                3
# Sao Tome and Principe    3
# Name: count, dtype: int64
#
# Top 3 Regions:
# Region
# Sub-Saharan Africa    36
# Europe                19
# Asia                  10
# Name: count, dtype: int64

# %% [markdown]
# **<span style="font-size:24px;">Calculating KPIs</span>**

# %%
# Total Revenue
total_revenue = Clean_data['Total Revenue'].sum()
print(f"Total Revenue: ${total_revenue:,.2f}")
# Out:
# Total Revenue: $104,233,116.00

# %%
# Total Profit
total_profit = Clean_data['Total Profit'].sum()
print(f"Total Profit: ${total_profit:,.2f}")
# Out:
# Total Profit: $33,821,335.00

# %%
# Total Cost
total_cost = Clean_data['Total Cost'].sum()
print(f"Total Cost: ${total_cost:,.2f}")
# Out:
# Total Cost: $70,411,739.00

# %%
# Total units sold
total_units_sold = Clean_data['Units Sold'].sum()
print(f"Total Units Sold: {total_units_sold:,}")
# Out:
# Total Units Sold: 450,286

# %%
#Average Unit Price
average_unit_price = total_revenue/total_units_sold
print(f"Average Unit Price: ${average_unit_price:,.2f}")
# Out:
# Average Unit Price: $231.48

# %%
#Average Unit Cost
average_unit_cost = total_cost /total_units_sold
print(f"Average Unit Cost: ${average_unit_cost:,.2f}")
# Out:
# Average Unit Cost: $156.37

# %%
#Profit Margin
profit_margin = total_profit / total_revenue
print(f"Profit Margin: {profit_margin:.2%}")
# Out:
# Profit Margin: 32.45%

# %%
#Calculating Return on Investment
ROI = (total_profit / total_cost) * 100
print(f"ROI: {ROI:.2f}%")
# Out:
# ROI: 48.03%

# %% [markdown]
# **<span style="font-size:24px;">Sales Trend Analysis</span>**

# %%
# Monthly Sales Trend
monthly_sales = Clean_data.groupby('Order Month')['Total Revenue'].sum().reset_index()

# Plotting the Monthly  Sales Trend
plt.figure(figsize=(10,6))
sns.lineplot(data=monthly_sales, x='Order Month', y='Total Revenue', marker='o')
plt.title('Month-wise Sales Trend (Aggregate across Years)')
plt.ylabel('Total Revenue')
plt.xlabel('Month')
plt.xticks(range(1, 13))  
plt.grid(True)
plt.show()

# %% [raw]
# Observations:
# Peak months are November and April show the highest revenues.
# Low months are August and December have the lowest revenues.
#
# Pattern that noticed here is that the revenue increases through the year, peaks in November, dips in summer, and declines sharply after November.

# %%
# Yearly Month wise Sales Trend
yearly_month_sales = Clean_data.groupby('Order Year_Month')['Total Revenue'].sum().reset_index()

# Plotting the Yearly-Month Sales Trend
plt.figure(figsize=(18, 6))
sns.lineplot(data=yearly_month_sales, x='Order Year_Month', y='Total Revenue', marker='o')
plt.title('Year-Month Sales Trend')
plt.ylabel('Total Revenue')
plt.xlabel('Year-Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [raw]
# Observations:
# Peak revenue is observed in february 2012 ($6.7M) and November 2016($5.9M) , marking revenue months.
# Yearly Trends show strong performance in February and November, with low-revenue months in summer.
# Low Revenue is seen in June 2011 and August 2015, each under $10,000.
#
# Patterns indicate November consistently has strong sales, while summer months often see lower revenue.

# %%
# Yearly Sales Trend
yearly_sales = Clean_data.groupby('Order Year')['Total Revenue'].sum().reset_index()

# Plotting the Yearly Sales Trend
plt.figure(figsize=(10, 6))
sns.lineplot(data=yearly_sales, x='Order Year', y='Total Revenue', marker='o')
plt.title('Year-wise Sales Trend')
plt.ylabel('Total Revenue')
plt.xlabel('Year')
plt.grid(True)
plt.show()

# %%
yearly_sales
# Out:
#    Order Year  Total Revenue
# 0        2010       13789445
# 1        2011       11129160
# 2        2012       28112044
# 3        2013       11784935
# 4        2014       16630208
# 5        2015        6914751
# 6        2016        8496212
# 7        2017        7376361

# %% [raw]
# observations:
# Peak Year is 2012, with the highest revenue at $28.1M.
# Lowest Year is 2015, with the lowest revenue at $6.9M.
# Recent Trend shows revenue decreased from 2014 to 2015, then slightly increased in 2016 but remained below peak levels.
#
# Overall Pattern indicates that revenue was highest in 2012 and fluctuated in subsequent years, with a notable drop in 2015.

# %%
# Yearly Profit Trend
year_profit = Clean_data.groupby('Order Year')['Total Profit'].sum().reset_index()

# Plotting the Year wise Profit Trend using a bar chart
plt.figure(figsize=(18, 6))
sns.barplot(data=year_profit, x='Order Year', y='Total Profit', color='skyblue')
plt.title('Year wise Profit Trend')
plt.ylabel('Total Profit')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.grid(axis='y')  
plt.show()

# %%
# A Pie Chart for Profit Distribution by Year
plt.figure(figsize=(6,6))
plt.pie(year_profit['Total Profit'], labels=year_profit['Order Year'], autopct='%1.1f%%', startangle=140, wedgeprops={'edgecolor': 'black'})
plt.title('Profit Distribution by Year')
plt.show()

# %%
year_profit
# Out:
#    Order Year  Total Profit
# 0        2010       5583330
# 1        2011       2741003
# 2        2012       7707114
# 3        2013       3316953
# 4        2014       5879454
# 5        2015       2629262
# 6        2016       3362130
# 7        2017       2602089

# %% [raw]
# Observations:
# 2012 stands out as the most profitable year with a notable $7.7M in total profit, well above the other years.
# 2011 had the lowest total profit at $2.7M, with 2013 and 2015 also showing lower profits, at $3.3M and $2.6M, respectively.
# 2014 was the second most profitable year with $5.8M, indicating strong performance but not quite reaching the heights of 2012.
# 2017 also had a lower total profit at $2.6M, aligning with the lower end of the profitability range seen in 2015.
#
# This summary provides a clear picture of the variability in profitability across the years, highlighting 2012 as the peak and 2011, 2015, and 2017 as the lower points.

# %% [markdown]
# **<span style="font-size:24px;">Factor-Wise Analysis</span>**

# %% [markdown]
# **<span style="font-size:20px;">Region</span>**

# %%
# Analyzing sales performance by region for Total Revenue and Total Profit
region_revenue_performance = Clean_data.groupby('Region', observed=False)['Total Revenue'].sum()
region_profit_performance = Clean_data.groupby('Region', observed=False)['Total Profit'].sum()

# Plotting Total Revenue and Total Profit
plt.figure(figsize=(14, 6))

# Plot Total Revenue
plt.subplot(1, 2, 1)
sns.barplot(x=region_revenue_performance.index, y=region_revenue_performance.values, color='teal')
plt.xlabel('Region')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by Region')
plt.xticks(rotation=45)

# Plot Total Profit
plt.subplot(1, 2, 2)
sns.barplot(x=region_profit_performance.index, y=region_profit_performance.values, color='orange')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.title('Total Profit by Region')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [raw]
# Observations:
#
#
# Sales Performance Across Regions:
#
# Highest Revenue: Sub-Saharan Africa ($39,672,014) leads in sales, suggesting a strong market presence.
# Lowest Revenue: Central America and the Caribbean ($3,173,328) has the lowest sales, indicating potential market challenges.
# Most Profitable Regions:
#
# Highest Profit: Sub-Saharan Africa ($12,183,195) is the most profitable, reflecting efficient cost management and high revenue.
# Lowest Profit: Central America and the Caribbean ($1,359,644) has the lowest profit, which may point to higher costs or lower profit margins.
# Regions with Higher Costs:
#
# Inferences: Regions like Europe and Middle East and North Africa show high revenue but moderate profits, suggesting potentially higher costs. Sub-Saharan Africa manages high revenue and profit well, indicating effective cost control.
#
# In summary, Sub-Saharan Africa excels in both revenue and profit, while Central America and the Caribbean lags behind. Regions with high revenue but lower profit might be facing higher costs.

# %% [markdown]
# **<span style="font-size:20px;">Country</span>**

# %%
# Analyzing sales distribution by country for Total Revenue
country_sales_distribution_revenue = Clean_data.groupby('Country', observed=True)['Total Revenue'].sum()

# Analyzing sales distribution by country for Total Profit
country_sales_distribution_profit = Clean_data.groupby('Country', observed=True)['Total Profit'].sum()

# Bar plot for Total Revenue & Profit by Country
plt.figure(figsize=(24,10))

# Plot Total Revenue
plt.subplot(1, 2, 1)
sns.barplot(x=country_sales_distribution_revenue.index, y=country_sales_distribution_revenue.values, palette='viridis', hue=country_sales_distribution_revenue.index, dodge=False)
plt.xlabel('Country')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by Country')
plt.xticks(rotation=90)

# Plot Total Profit
plt.subplot(1, 2, 2)
sns.barplot(x=country_sales_distribution_profit.index, y=country_sales_distribution_profit.values, palette='plasma', hue=country_sales_distribution_profit.index, dodge=False)
plt.xlabel('Country')
plt.ylabel('Total Profit')
plt.title('Total Profit by Country')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [raw]
# Observations:
#
# Sales Distribution:
# Top Revenue: The Gambia ($5.4M), Turkmenistan ($5.8M), Azerbaijan ($4.5M).
# Lowest Revenue: United Kingdom ($188K), Albania ($248K).
#
# Top Contributors:
# Revenue: The Gambia, Turkmenistan, Azerbaijan.
# Profit: Azerbaijan, The Gambia, Turkmenistan.
#
# High Costs Relative to Revenue:
# United Kingdom and Austria may have high costs compared to their revenue.
#
# Summary: The Gambia and Turkmenistan lead in revenue, while Azerbaijan is strong in both revenue and profit. Countries with lower profit margins like United Kingdom and Austria may face higher relative costs.

# %% [markdown]
# **<span style="font-size:20px;">Item Types</span>**

# %%
# Analyzing item type popularity and profitability
item_type_popularity = Clean_data.groupby('Item Type',observed=True)['Units Sold'].sum()
item_type_profitability = Clean_data.groupby('Item Type',observed=True)['Total Profit'].sum()

# Bar plot for item type popularity and profitability
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

sns.barplot(x=item_type_popularity.index, y=item_type_popularity.values, ax=ax[0])
ax[0].set_xlabel('Item Type')
ax[0].set_ylabel('Units Sold')
ax[0].set_title('Units Sold by Item Type')
ax[0].tick_params(axis='x', rotation=45)

sns.barplot(x=item_type_profitability.index, y=item_type_profitability.values, ax=ax[1])
ax[1].set_xlabel('Item Type')
ax[1].set_ylabel('Total Profit')
ax[1].set_title('Total Profit by Item Type')
ax[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [raw]
# Observations:
#
# Most Popular Items (Units Sold):
# Clothes (71,260 units)
# Personal Care (48,708 units)
# Cosmetics (46,644 units)
#
# Most Profitable Items:
# Cosmetics ($8.1M)
# Clothes ($5.2M)
# Household ($4.6M)
#
# Cost Insights:
# High Profit: Likely indicates better cost management or higher prices.
# Low Profit: May indicate higher costs or lower prices.
#
# Summary: Clothes and Personal Care are top sellers, while Cosmetics is the most profitable. Costs likely influence profit margins, with high-profit items having better cost control.

# %% [markdown]
# **<span style="font-size:20px;">Sales Channel</span>**

# %%
# Analyzing sales channel performance
sales_channel_performance = Clean_data.groupby('Sales Channel',observed=True)[['Total Revenue', 'Total Profit']].sum()

#Bar plot for total Revenue and Total Profit by Sales Channel
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot Total Revenue by Sales Channel
sns.barplot(x=sales_channel_performance.index, y=sales_channel_performance['Total Revenue'], ax=ax[0])
ax[0].set_xlabel('Sales Channel')
ax[0].set_ylabel('Total Revenue')
ax[0].set_title('Total Revenue by Sales Channel')
ax[0].tick_params(axis='x', rotation=45)

# Plot Total Profit by Sales Channel
sns.barplot(x=sales_channel_performance.index, y=sales_channel_performance['Total Profit'], ax=ax[1])
ax[1].set_xlabel('Sales Channel')
ax[1].set_ylabel('Total Profit')
ax[1].set_title('Total Profit by Sales Channel')
ax[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [raw]
# Observations:
#
# Sales Channel Effectiveness:
# Offline: Higher revenue ($54M) and profit ($17.8M) than Online.
#
# Effectiveness for Item Types:
# Offline generally performs better, but specifics depend on item type data.
#
# Cost Differences:
# Offline may have lower costs or higher margins compared to Online.
#
# Insight: Offline channels are more profitable and generate more revenue.

# %% [markdown]
# **<span style="font-size:20px;">Order Priority</span>**

# %%
# Analyzing order priority
order_priority_profit = Clean_data.groupby('Order Priority',observed=True)['Total Profit'].mean()
order_priority_cost = Clean_data.groupby('Order Priority',observed=True)['Total Cost'].mean()

#Bar plot for Average Profit and Average Cost by Order Priority
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

sns.barplot(x=order_priority_profit.index, y=order_priority_profit.values, ax=ax[0])
ax[0].set_xlabel('Order Priority')
ax[0].set_ylabel('Average Profit')
ax[0].set_title('Average Profit by Order Priority')
ax[0].tick_params(axis='x', rotation=45)

sns.barplot(x=order_priority_cost.index, y=order_priority_cost.values, ax=ax[1])
ax[1].set_xlabel('Order Priority')
ax[1].set_ylabel('Average Cost')
ax[1].set_title('Average Cost by Order Priority')
ax[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [raw]
#  Observations:
#
# Correlation with Profitability:
# Highest Profit: High-priority (H) orders ($435K).
# Lowest Profit: Critical (C) orders ($247K).
# Insight: High-priority orders seem to correlate with higher profitability, but Critical orders are the least profitable.
#
# Effect on Shipping Times:
# No shipping time data is provided, but typically, high-priority orders are expected to have faster shipping times.
#
# Cost to Fulfill High-Priority Orders:
# Most Expensive: Medium-priority (M) orders ($1.05M cost).
# Least Expensive: Critical (C) orders ($465K cost).
#
# Insight: High-priority orders (H) have lower costs than M, suggesting high-priority orders may not always be the most costly to fulfill.
#
# Summary:
# High-priority orders have higher profits, while Critical orders are the least profitable.
# Medium-priority orders have the highest costs, not necessarily High-priority ones.

# %% [markdown]
# **<span style="font-size:20px;">Units Sold</span>**

# %%
# Analyzing units sold distribution and effect on profit
units_sold_distribution = Clean_data['Units Sold'].describe()
units_sold_vs_profit = Clean_data.groupby('Units Sold')['Total Profit'].mean()

# Scatterplot for Unit sold vs Average Profit
plt.figure(figsize=(12, 6))
sns.scatterplot(x=units_sold_vs_profit.index, y=units_sold_vs_profit.values)
plt.xlabel('Units Sold')
plt.ylabel('Average Profit')
plt.title('Units Sold vs. Average Profit')
plt.show()

# %%
units_sold_distribution
# Out:
# count      93.000000
# mean     4841.784946
# std      2681.106131
# min       124.000000
# 25%      2370.000000
# 50%      5062.000000
# 75%      6952.000000
# max      9925.000000
# Name: Units Sold, dtype: float64

# %% [raw]
# Observations:
#
# Distribution of Units Sold per Order:
# The number of units sold ranges from 124 to 9,925, with an average of about 4,841 units per order.
# The distribution suggests that 25% of orders sell fewer than 2,370 units, while 75% sell fewer than 6,952 units. The highest order sold 9,925 units.
#
# Effect of Units Sold on Total Profit:
# There seems to be a positive correlation between units sold and total profit. For example, orders with higher units sold (9,905 units) generated significantly higher profits (727,423 in profit).
# However, some orders with fewer units sold, like 273 units, still produced a notable profit (6,841). This suggests that the type of product or cost structure could also influence profitability.
#
# Items or Regions with High/Low Units Sold:
# The data shows variability in units sold, which may point to certain item types or regions consistently selling higher or lower quantities. For instance, larger orders may be more common in regions with strong demand or for essential items.
#
# To analyze these trends further, it would be helpful to cross-reference Units Sold with Item Type or Region to see where the demand is concentrated.

# %% [markdown]
# **<span style="font-size:24px;">Correlation Analysis</span>**

# %%
# Select only numeric columns
numeric_Clean_data = Clean_data.select_dtypes(include=[np.number])
correlation=numeric_Clean_data.drop(columns={'Order ID'})#only for correlation droped the order id column

#Checking the Correlation:
plt.figure(figsize=(12, 8))
sns.heatmap(correlation.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f', linewidths=0.5, linecolor='black')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# **Strong Correlations:**
# Total Revenue vs. Total Cost (0.98): As revenue increases, costs rise proportionally, indicating a close relationship between revenue and costs.
#
# Unit Price vs. Unit Cost (0.99): Higher unit prices are strongly linked to higher unit costs, showing a direct relationship between pricing and cost structure.
#
# Total Revenue vs. Total Profit (0.87): Strong positive correlation, meaning high revenue is associated with high profit.
#
#
# **Moderate Correlations:**
# Units Sold vs. Total Profit (0.45): More units sold generally lead to higher profits, though not as strong as revenue or costs.
#
# Units Sold vs. Total Revenue (0.30): Selling more units slightly boosts revenue, but other factors like pricing also play a role.
#
# **Weak Correlations:**
# Units Sold vs. Unit Price (-0.20): There’s a slight negative correlation, suggesting higher sales volumes might result in slightly lower unit prices.
#
# Order Year/Month vs. Financial Metrics (-0.12 to 0.03): Minimal correlation between the year or month of the order and financial performance (revenue, cost, profit).
